# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('mode.chained_assignment', None)

# %%
kk = pd.read_csv('VIXDaily.csv', index_col=0, header=None)
print(kk)
# Out:
#                     1
# 0
# 2019-03-01  14.845208
# 2019-03-04  18.808728
# 2019-03-05  19.309780
# 2019-03-06  20.434427
# 2019-03-07  20.450502
# ...               ...
# 2021-08-04  18.360570
# 2021-08-05  18.194022
# 2021-08-06  18.394132
# 2021-08-09  18.048022
# 2021-08-10  18.381315
#
# [597 rows x 1 columns]

# %%
plt.plot(kk[-15:])
